# %%
from gensim.models import Word2Vec, keyedvectors
import gensim.downloader as api

# %%
wv = api.load('word2vec-google-news-300')
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
wv["Suraj"]
# Out:
# array([ 0.24511719,  0.36132812, -0.03588867,  0.12597656, -0.02990723,
#        -0.1328125 , -0.21679688, -0.20117188, -0.45117188, -0.18945312,
#         0.03930664,  0.21484375, -0.13476562,  0.07177734, -0.29296875,
#         0.20214844,  0.25585938, -0.25195312, -0.16015625,  0.23730469,
#         0.07373047, -0.37890625,  0.08984375, -0.03417969, -0.24902344,
#        -0.1484375 , -0.07080078, -0.06884766,  0.09716797, -0.23828125,
#        -0.17871094, -0.23144531,  0.11914062, -0.11767578, -0.05126953,
#        -0.02075195, -0.14941406,  0.02099609, -0.01092529, -0.47265625,
#         0.23632812,  0.09423828,  0.203125  ,  0.2578125 , -0.20800781,
#        -0.10058594, -0.18359375, -0.12988281,  0.16210938, -0.2265625 ,
#         0.04736328,  0.265625  ,  0.37109375, -0.21777344,  0.08740234,
#         0.09716797,  0.04492188, -0.04370117, -0.05078125, -0.41210938,
#         0.328125  ,  0.07177734,  0.01879883, -0.06005859, -0.18359375,
# ...

# %%
len(wv["Suraj"])
# Out:
# 300

# %%
wv.most_similar("Suraj")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 wv.most_similar("Suraj")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\gensim\models\keyedvectors.py:823, in KeyedVectors.most_similar(self, positive, negative, topn, clip_start, clip_end, restrict_vocab, indexer)
#     820 positive = _ensure_list(positive)
#     821 negative = _ensure_list(negative)
# --> 823 self.fill_norms()
#     824 clip_end = clip_end or len(self.vectors)
#     826 if restrict_vocab:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\gensim\models\keyedvectors.py:708, in KeyedVectors.fill_norms(self, force)
#     700 """
#     701 Ensure per-vector norms are available.
#     702
#    (...)
#     705
#     706 """
#     707 if self.norms is None or force:
# --> 708     self.norms = np.linalg.norm(self.vectors, axis=1)
#
# ...
